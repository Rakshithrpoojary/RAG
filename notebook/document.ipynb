# %%
### What exactly is document data structure
from langchain_core.documents import Document

# %%
doc = Document(
    page_content="This is Rakshith learning AWS",
    metadata={
        "sourec":"example.txt",
        "pages":1,
        "author":"Rakshith",
        "date_created":"2024-01-01"
    }
)
print(doc)
# Out:
# page_content='This is Rakshith learning AWS' metadata={'sourec': 'example.txt', 'pages': 1, 'author': 'Rakshith', 'date_created': '2024-01-01'}

# %%
import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""
    Python is a popular programming language. It was created by Guido van Rossum, and released in 1991.

It is used for:

web development (server-side),
software development,
mathematics,
system scripting.
What can Python do?
Python can be used on a server to create web applications.
Python can be used alongside software to create workflows.
Python can connect to database systems. It can also read and modify files.
Python can be used to handle big data and perform complex mathematics.
Python can be used for rapid prototyping, or for production-ready software development.
Why Python?
Python works on different platforms (Windows, Mac, Linux, Raspberry Pi, etc).
Python has a simple syntax similar to the English language.
Python has syntax that allows developers to write programs with fewer lines than some other programming languages.
Python runs on an interpreter system, meaning that code can be executed as soon as it is written. This means that prototyping can be very quick.
Python can be treated in a procedural way, an object-oriented way or a functional way.

    """
}
for file,content in sample_texts.items():
    with open(file,'w',encoding="utf-8") as f:
        f.write(content)

# %%
from langchain_community.document_loaders import TextLoader
loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='\n    Python is a popular programming language. It was created by Guido van Rossum, and released in 1991.\n\nIt is used for:\n\nweb development (server-side),\nsoftware development,\nmathematics,\nsystem scripting.\nWhat can Python do?\nPython can be used on a server to create web applications.\nPython can be used alongside software to create workflows.\nPython can connect to database systems. It can also read and modify files.\nPython can be used to handle big data and perform complex mathematics.\nPython can be used for rapid prototyping, or for production-ready software development.\nWhy Python?\nPython works on different platforms (Windows, Mac, Linux, Raspberry Pi, etc).\nPython has a simple syntax similar to the English language.\nPython has syntax that allows developers to write programs with fewer lines than some other programming languages.\nPython runs on an interpreter system, meaning that code can be executed as soon as it is written. This means that prototyping can be very quick.\nPython can be treated in a procedural way, an object-oriented way or a functional way.\n\n    ')]

# %%
### Directory loader
from langchain_community.document_loaders import DirectoryLoader
from langchain_community.document_loaders import PyPDFLoader,PyMuPDFLoader

dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf",
    loader_cls=PyMuPDFLoader,
    show_progress=False
)
documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'producer': 'macOS Version 13.4 (Build 22F66) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20240324062134Z00'00'", 'source': '..\\data\\pdf\\ASHIQ_DEVOPS_ENGINEER_J2_V02.pdf', 'file_path': '..\\data\\pdf\\ASHIQ_DEVOPS_ENGINEER_J2_V02.pdf', 'total_pages': 3, 'format': 'PDF 1.4', 'title': 'MOHAMMED_ASHIQ_J2_V02', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20240324062134Z00'00'", 'trapped': '', 'modDate': "D:20240324062134Z00'00'", 'creationDate': "D:20240324062134Z00'00'", 'page': 0}, page_content='ASHIQ U \nDevOps Engineer \n+91-7907558767 \nashiqummathoor@outlook.com \nLinkedIn \nOBJECTIVE\nSUMMARY\nEnthusiastic about tackling challenging roles and collaborating with diverse teams to drive \norganisational success. Possessing extensive experience across various cloud and on-premises \nenvironments, I am dedicated to implementing high availability and resilient architectures. With \na clear, logical mindset and a practical approach to problem-solving, I strive to see projects \nthrough to successful completion, contributing effectively to team objectives.\n๏Over 4+ years of experience in AWS, Azure, GCP and On-Premise. \n๏Managed 40+ kubernetes clusters across DEV, STG and PRD for multiple customers. \n๏Executed successful migration from 48+ ECS services to EKS Kubernetes. \n๏Extensive experience with multiple CI/CD tools such as AWS CodePipeline, CircleCI, \nTekton, Drone.io, GoCD, Jenkins, BitBucket Pipelines and Argo CD workflows. \n๏Implemented highly available Redis clusters with multi-node configurations. \n๏Efficiently managed and implemented data migration projects, including a migration of \nover 200 TB from GCP to AWS. \n๏Having hands-on experience with Terraform, Serverless Framework (SLS), and eksctl for \nefficient infrastructure provisioning and management. \n๏Implemented KEDA and Horizontal Pod Autoscaler (HPA) based on Kafka events and \ncron scaling, ensuring seamless scale-out and scale-in in peak hours.  \n๏Created AWS EMR clusters with 50 nodes for data migration for GCP to AWS. \n๏Implemented AWS Media Converter to optimise video delivery by segmenting videos into \nsmaller chunks and reducing buffering through CDN. \n๏Having Deep knowledge in containerisation and orchestration technologies. \n๏Helped customer to reduce their infra cost initiating cost optimisation strategies (AWS). \n๏Implemented production-level monitoring solutions using Grafana, Loki, and Mimir to \nmanage high volumes of logs effectively. \n๏Implemented AWS and Google Single Sign-On (SSO) and VPN to make completely \nprivatised infrastructure application to ensure comprehensive security and isolation from \nvulnerabilities and threats. \n๏Extra ordinary communication skills can work with other team member and customers.  \n๏Experience in different Orchestration tools such as Docker Swarm and Kubernetes. \n๏Extremely quality conscious and Attention to detail in handling and documenting technical \nissues.  \n๏Having experience in infra monitoring to ensure application stability and performance.\nBengaluru'),
#  Document(metadata={'producer': 'macOS Version 13.4 (Build 22F66) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20240324062134Z00'00'", 'source': '..\\data\\pdf\\ASHIQ_DEVOPS_ENGINEER_J2_V02.pdf', 'file_path': '..\\data\\pdf\\ASHIQ_DEVOPS_ENGINEER_J2_V02.pdf', 'total_pages': 3, 'format': 'PDF 1.4', 'title': 'MOHAMMED_ASHIQ_J2_V02', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20240324062134Z00'00'", 'trapped': '', 'modDate': "D:20240324062134Z00'00'", 'creationDate': "D:20240324062134Z00'00'", 'page': 1}, page_content='TECHNICAL SKILLS\n๏Cloud: AWS, Microsoft Azure, and GCP \n๏On-Premise: Microk8s, KubeAdmin, Redis-Cluster and MongoDB Cluster \n๏Monitoring: Grafana, Prometheus (Mimir), Loki, Tempo, Zipkin, New-relic and Coroot \n๏Scripting: Python , Shell Scripting \n๏VPN: Pritunl, OpenVPN and AWS VPN endpoint   \n๏AWS Services: VPC, Datasync, EC2, MediaConverter, EventBridge, ElasticBeansStalk, \nAmplify, Lightsail, IAM, SSO, Organisation, Route53, EBS, EFS, S3, CDN, WAF, \nCloudMap, EMR, \n Systems Manager, CloudWatch, CloudTrial, ECS, EKS, ECR, \nCodePipeline, CodeBuild, CodeCommit, Athena, ACM, MSK, ElasticCache, SQS, SNS, \nSES, Billing, Batch, Step Function, Lambda, DynamoDB, RDS, Secret Manager, Cloud \nFormation and ChatBot..etc \n๏Azure Services: AD, VM, Load Balancer, Application Gateway, CDN, Traffic Manager, \nAzure Firewall, Blob, File Share,  Queue and Table, AKS, On-Prem Backup (MARS), Azure \nsite Recovery, Azure Bastion Host. \n๏DevOps Tool Kit: Docker, Kubernetes, Docker Swarm, Terraform, Ansible, CICD-\nCodePipeline, CodeBuild, CircleCi, Jenkins, Tekton, GoCD, Git Workflow and bucket \npipelines, GitHub, Monitoring-Grafana, Prometheus, Loki, and Tempo Stack, \nOrchestration-ECS, EKS, CF, GKE, AKS and most of the CNCF tools. \n๏Database: (SQL and No-SQL) MYSQL, Postgres, DynamoDB and MongoDB. \n๏CNCF and Infra Tools: ArgoCD, Argo Rollouts, Argo events, Argo Workflow, Argo \nNotification, Argo Image Updater, Minio, Redash, Grafana, Open Telemetery, Containerd, \nEnvoys, Helm, Fluentd, Istio, Linkerd, Keda, Karpenter, Harbor, Metabase, RedisUI, \nKafkaUI, Homer, GrowthBook, Passbolt, Redmine. \nPROFESSIONAL EXPERIENCE\nBetaflux Consulting Private Limited \nDevOps Engineer \nPidge, Haven, Rideriver and hubbler\nMarch 2023 - Present\n๏Proficiently designed and implemented end-to-end infrastructure solutions for multiple clients, \nencompassing development, staging, and production environments from the ground up. \n๏Skilfully utilised DataSync and EMR to orchestrate the efficient migration of 200 TB data, \ntransitioning seamlessly from GCP to AWS with a keen emphasis on cost optimisation. \n๏Possessing extensive expertise and hands-on experience in managing Kubernetes clusters, \nincluding Amazon Elastic Kubernetes Service (EKS), Google Kubernetes Engine (GKE), and \nAzure Kubernetes Service (AKS). \n๏Helped client in optimising their video content streaming infrastructure by leveraging AWS \nMedia Converter for latency reduction, complemented by CDN and AWS S3 Transfer \nAcceleration and caching mechanisms. \n๏Having proficient experience in orchestrating automated Continuous Integration and \nContinuous Deployment (CICD) pipelines, utilising a diverse array of tools including AWS'),
#  Document(metadata={'producer': 'macOS Version 13.4 (Build 22F66) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20240324062134Z00'00'", 'source': '..\\data\\pdf\\ASHIQ_DEVOPS_ENGINEER_J2_V02.pdf', 'file_path': '..\\data\\pdf\\ASHIQ_DEVOPS_ENGINEER_J2_V02.pdf', 'total_pages': 3, 'format': 'PDF 1.4', 'title': 'MOHAMMED_ASHIQ_J2_V02', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20240324062134Z00'00'", 'trapped': '', 'modDate': "D:20240324062134Z00'00'", 'creationDate': "D:20240324062134Z00'00'", 'page': 2}, page_content='๏Equipped with comprehensive expertise in multi-cloud environments, with adept knowledge \nspanning across AWS, Azure, and GCP. \n๏Possessing extensive knowledge and hands-on experience in deploying applications in \nKubernetes, leveraging best practices to ensure efficient, scalable, and resilient containerised \nenvironments. \n๏Proficient in Argo CD, Rollouts, and Workflows, adeptly leveraging these tools to streamline \nand orchestrate deployment processes for seamless and efficient application rollout. \n๏Effectively managed over 40+ Kubernetes clusters across development, staging, and \nproduction environments, catering to the needs of more than 15 diverse customers, ensuring \nseamless operations and optimal performance. \n6D Technologies \nInfra solution Engineer \nNayan\nFebruary 2020 - March 2023\n๏Engineered a highly available Redis cluster solution for a client, implementing automatic \nfailover capabilities utilising Redis and Redis Sentinel to ensure continuous operation and \nuninterrupted service delivery.  \n๏Successfully created and managed MicroK8s and kubeadm on on-premise servers, ensuring \nrobust, scalable, and efficient container orchestration \n๏Engineered automation solutions for Linux systems focusing on clean storage management \namong other activities, significantly improving system efficiency and reliability. \n๏Implemented comprehensive monitoring solutions for infrastructure, enabling immediate \nactions on infra-related issues and substantially reducing downtime. \n๏Spearheaded the implementation of SSO for Jenkins, enhancing security and streamlining user \naccess management across the organisation.\n๏Worked extensively with GoCD pipeline, facilitating customer migration from cloud vendors \nand promoting cloud-agnostic practices to enhance operational flexibility and reduce \ndependency.\nEDUCATIONAL QUALIFICATIONS\n๏B. Tech Computer Science and Engineering 2015 - 2019  \n๏Higher Secondary (Kerala State Board) – 2013  \n๏Secondary School (Kerala State Board SSLC) – 2012 \u2028\nDECLARATION\n     I am keen to continue my career and prepared to work hard to achieve my organization \nobjectives and I hereby declare that the information furnished above is true to the best of my \nknowledge.')]
